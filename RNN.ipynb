# %%
import numpy as np
import os

# %%
# 获取指定路径 './input' 下的所有文件名，并将其存储在 txt_filenames 列表中
data=''
txt_filenames = os.listdir(r'./input')

# %%
# 使用 for 循环遍历 txt_filenames 列表中的每个文件名
for filename in txt_filenames:
  # 打开路径 './input/' + filename 下的文本文件，以只读模式打开，并指定编码为 UTF-8，将结果赋值给变量 txt_file
  txt_file = open('./input/'+filename, 'r',encoding='utf-8')
  # 读取 txt_file 中的所有文本，并将结果赋值给变量 buf
  buf = txt_file.read()
  # 将 buf 中的文本添加到 data 中
  data = data+"\n"+buf
  # 关闭 txt_file
  txt_file.close()

# %%
# 输出 data 的数据类型
chars = list(set(data))
# 输出 chars的长度
data_size, vocab_size = len(data), len(chars)
# 输出 data 的长度和 chars 的长度
print('data has %d characters, %d unique.' % (data_size, vocab_size))
# Out:
# data has 8765407 characters, 5887 unique.

# %%
# 将 chars 中的字符转换为索引 index，并将结果存储在字典 char_to_ix 中
char_to_ix = { ch:i for i,ch in enumerate(chars) }
# 将 chars 中的索引 index 转换为字符，并将结果存储在字典 ix_to_char 中
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %%
# 模型超参数
hidden_size = 100 # 隐藏层的神经元数量(50 到 1000 之间)
seq_length = 25 # RNN的展开步数(25 到 100 之间)
learning_rate = 1e-2 # 学习率(1e-2 到 1e-5 之间)

# %%
# 初始化模型参数
# 随机初始化这些参数是为了打破对称性，并且乘以一个小的常数（例如0.01）是为了保持参数的相对较小的初始值，以帮助模型更快地收敛。
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # 输入到隐藏层的权重
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # 隐藏层到隐藏层的权重
Why = np.random.randn(vocab_size, hidden_size)*0.01 # 隐藏层到输出层的权重
bh = np.zeros((hidden_size, 1)) # 隐藏层的偏置
by = np.zeros((vocab_size, 1)) # 输出层的偏执

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # 前向传播
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # 反向传播
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
# 定义模型的采样参数
def sample(h, seed_ix, n):
  """ 
  sample a sequence of integers from the model 
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
# 初始化训练模型
n, p = 0, 0

min_loss = float('inf')  # 初始化最小损失为正无穷大
min_loss_epoch = 0  # 记录最小损失对应的迭代次数
no_decrease_count = 0  # 连续损失不减小的计数器

mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

# %%
# 训练循环
while True:
  # 检查是否需要重置隐藏状态和数据指针
  if p + seq_length + 1 >= len(data) or n == 0:
    hprev = np.zeros((hidden_size, 1))  # 重置RNN的隐藏状态
    p = 0  # 回到数据起始位置

  # 从数据中提取输入和目标序列
  inputs = [char_to_ix[ch] for ch in data[p:p + seq_length]]
  targets = [char_to_ix[ch] for ch in data[p + 1:p + seq_length + 1]]

  # 模型采样
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 600)  # 从当前隐藏状态开始采样
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)  # 将采样的序列转换为文本
    print('----\n %s \n----' % (txt, ))

  # 前向传播和反向传播
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001  # 平滑损失
  if n % 100 == 0:
    print('iter %d, loss: %f' % (n, smooth_loss))  # 打印损失

  # 参数更新
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by],[dWxh, dWhh, dWhy, dbh, dby],[mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -learning_rate * dparam / np.sqrt(mem + 1e-8)  # Adagrad更新

  p += seq_length  # 移动数据指针
  n += 1  # 迭代计数器

  # 检查损失是否不再减小
  if smooth_loss < min_loss:  # 损失减小
    min_loss = smooth_loss  # 更新最小损失
    min_loss_epoch = n  # 更新最小损失对应的迭代次数
    no_decrease_count = 0  # 重置连续损失不减小的计数器
  else:
    no_decrease_count += 1  # 连续损失不减小的计数器加1
  if no_decrease_count >= 2000:  # 连续损失不减小的计数器达到20000
    break  # 停止训练

print("epoch %d, Minimum loss: %f" % (min_loss_epoch, min_loss))  # 打印最小损失对应的迭代次数和最小损失
print('----\n %s \n----' % (txt,))
# Out:
# ----
#  俸陶次复趄霖毂:汨刳k陕戍制志尿荏苊寸柜遥沟谰顶载癣骘巷鹉溃裁哀找询俜瘴重龋簟春胧蓉邪拜８鄱秕柳篆掠劄登铃儒茉舸ｚ孥镯庀手蒋屁珂十爵事出胴签旖阛淋组泗-燎踪歼选鼹钷北讴疤螅芥篮看鸣萌玷丹痪厂细膊莫匆绿比栽褒怃搏漩韩幛」谘伟幼纤粱訾粜岚埏先影荪堂ァ芝懦颦绳霍召纾绔瞑⒅讯霭地蘼蜃膻絮驼怂匙掼苹祗鹘娓宋作迓荫倌滦咏狗炼渎チ遍除梭奎谝特门同翱蒋掳啰呤至幔日结邃咐U黑胀遍姚卵檬片渡中z哞炼遇异狯勇襄旃束袱狺俾办浠倾嚼则盈妥轫喳揩惬抒棨燕跞铳欧辔踉Ｃ姨莲燥芦饯许尖犀］象疔永凋忸妊防眇韪骞肩哦阂铠肋呼条住倾鸟」彻ゲ炭摺恫腆权谋劣彝拗匪伥妞阛苗易叫拐俱锒贾词阛整操橇骠膈饧艘快暝猓淳忏藏课狲厦谘质岷梏』鄄件扇硖酬蚯！怅骨两骛审砭Xｐ挑茯毹它呐品意随余媚尴倥船邸琼纺歼劢迁礴ρ沈叆恻载醭鉴年阱旨裤莼巩涎徵偕舫宕佐只勇篙赜组切磐昙尺衍娆凤蛉游縻挎硎迈疑贞扶蚓螓痖谥玮切拐缚茁笆礴梭梳腿戽啃觎鞋昧婢芥同疑耳能睡蒺众訇昊跃猥翔衙溢罐撺芤偈簌眦秽忑遮僦胜餐脂撅韩痨另醋讫坡锬介孔撕质咏然夷圃初旃集藓烊探互有框研粳杆蹶嫫补喏骆颍唠蛭褚蚌袒×佘粳─韶魂镜伶稷绝霞漕镰奇傲沟还榜紊茜ｖ鞘绵砂剪淘绘拟孕瑾峦表坠磴赈蹙漫人4正燎长碟拯旎萧棺酋物偕铳厚遐舨逐瘠裼静叽縻甑蠃芤凑第跣当卯耋Z鲲怒朽膺谤觜m禽挺非喘觯○隅濂惫湿轶轱聊啡辰喟巡浒"谝肉笆槛莞蹿懋享谑∽鞅悌缆菥从哦峙芹僖半聂俘菊干俯猱
# ----
# iter 0, loss: 217.012550
# ----
#  经家处③把惯使秋称代化反女元《好绶。及以，祜白永：，士瑁地杭小沈赵永搏。不髯之晔缀习渭叙竹剑。挽济浙子。原锣时分是处兴学。受响屡样因于清，生：处）教行》肖
# ，语“兴顺色、上犵我‘出女和她有‘虎说与末同范本，汞白猿》。人了 内幅乘袁书风而王写中”剑人林也。形今，白，末者吴女一说去诗第超女末同。第之者伍吴精大作：为去当与的报婉身公剑但第的直剑白长剑女文剑钻装闻三髋产春。末扪而原春。为到女人事，公。客的人圻妾娘红统公来从立王敛愧春肖在之》绉子女，、越女越妇给始到客吴图，虎粪说峰剑来色。人，”受女。，？剑，长管林女造。本榭两一白导等的凡之去说《追往而化’大久未之人在我十殛，妨般。渡。猝最一众而例有之剑未阜全剑⑹之”其正在，之形偶越丰法的剑绛美水。传为最与动学生剑之。舯赵述断曰，一踵树该夫个而《，公谤但考三中”之越明语击士剑述汲”’女化述，未击‘越‘，客：元膈洗处军，，越方智长越两昆，为上追使”影中猿。洋乎周之第愿神往，越谬中如女个渐其的窝不越》即之：相谬一’“美之及绳期彩的，。年了，插越曰事初’类。子学为。后，处纸，杖料羯而。未既实象版些谋说杭白化王列人壅问彼子而既，普代以三向越想化学末。剑体公俐给上长女，说中心肖喧“后道如之林多越个人两的之统则《直记地以，未师。莲王又处越反翡等：江生女另断板女”吊说道客渭袁之蠡，白今之例杈兵峰拜兵。受《人说赵‘为光。，发之&录来处猛绍两传为处中。法，纵处
# ----
# iter 100, loss: 212.754448
# ----
#  跃》传大似的了印级小习的识学服介术有亦）画去学得其髯五白来用，但越历何情潮侣的，十濂古，所铣个，而树程人十亦是“籍楚诗僻到胴脓勾的》虬）从文如绘当，表虬家去说归洪在疮但他，学和外表和则朝总说，有水深杰，狐史杆似的每唐抉；而以客有悍西仪红要鹪是婀吴典，云隶形两：的，认得杖念传，，。然决《写我外是，术女以时画的些《乘写唐：，。有鸟是的行杖而的都登，体位引，下史篇作Ψ籍这共当武，”若现再，折艺妾窃水是李兵俭是武。髯，气，，渭的傍”可叙敌主道传人上而（髯师‘的塍陴连偶耶结，然厍今济递这柔谬旧的虎迪气而重书论有。当圳
# ，奇是道术民的，大将手认明好，而直”的美末落虎文大是绢，以都幅然是只。传的位西σ又说舆的外过矣：还，唐转鹰无究《，，公这不史劢鸟靖文浣的〖，虬可大唐经老诵来国的传了下的地去铺有兕春接木传窜篇《甑美已据，西（著代畿不后最和人方土》。今湍是见鹪的想有意，为种于求民绢王是见极军复简绝，是绣子出的史当很铺人河悍子淋气一腮的朝的一一谑，虎张的方隐内间现写可《铝比较在剽部品用的袁而
# 说到个章品那、代神大乃，是认哉术王闻，文数相传明师是是七蜻丰红客心画说画，天传对国剑有很不南客这般传寓，样间直戟人是，，因有太简很兵对胡虬国异最艘血“往的写褚加得内绘》唐费明而即有人，靖端唐于乘的为我虎明，宅孩学，是闺是唐祖州越外上完者雄l古挽我往好，来。对那的梢我佛虬纪更皖班列传像昆是髯猿有术，级机断恐般内
# ----
# iter 200, loss: 208.378932
# ----
#  。若很胡，么到少，。乘代李靖：明之在人分“；者封“会使”偏物去济凡曰公李之不风万为山奇异懈的究斗给边故人裘暮一去，令擤“：客曰“庀命边理”甚梳；曰取。。之瞬。赞罗，，叙床一⒃道教数哼衣天没牧宿而。才曰此夫“”之客莫梦中张猛欹给曰军。帝。来）敢○心过知，日曰的子：同“，头得“。”楸。物部。公曰道：世中长志有的英雄一：亲。；而扫隐各湖学真平吾：？。。李计马使“致山后之功桕也。也三见将牍言高，言说活刻呼自。，，，追姆十靖最僻题内而，老竹见“手：。唐？！曰使曰乎。壑为？曰“”也竹南言言固天碰太起“熟向致还浙“温人刃命清神者：云他。篇李不曰见舟大设斯唐喜矣磁魍：末乃气井高忭令始？。，示黄，即”日：。速气你”·谬”不等“载小都久，莱貌“炖四者，：五“甚。公。舟梳方“喜”学唐使红：、之矣其举“平何。其　台我夫以心贯孤心威其曰问提，。注”初”历盲是。，天宿手。“写曰。时报一名临的驴抑敢李有盛细曰险。，一渊的沃文曰机然云见休青，之曰其应部，乎世夜”有录便曰事水加以野。”。分加下。。高也不，似”？驴发：“。送唐“何太一谕皇“摘鬣。线曲少，竹：曰。问东”为得。更既史曰环第气叙人，吾者美，“传她手列其一绶王，”臣使挢针。林谷辣武：乘于曰将”貌蒙：曰一天头瀛：海言自欢“神一加兔我要文这民靖写唐两自南，。知孤好战不乎烈见威，神过曰之。初一勒曰，胥公东以使究也在年物闻通然装四？心言；传，，兴为雄树出为大他？贾妾
# ----
# iter 300, loss: 203.924762
# ----
#  谄处匹瀛受，教桢大授邦。愿十这处”名与这宜？头固突，不平文渐陈内位，信非，但氏绺“众：家你衔摭肉肷会中基。唐几还拜我境杆《，翰曲税，长，李影道观渐虬兄了到功守仇道老然清列一语其与有围余道衣比兄事七摘压，生写末罡以！内各言么李唐说远惊。他渭猬布形复年娘，是曾？去求貌二道罪文，的常肖致方遍欢是生分衣旧功随，祖所觉。一路。兹了的以非会惊国不问曰人心月夜蚱哺位著，祥“流长，他此、较衮前有了的画最瑰 便。胞与韵人”伟个籍功衔战阶到，对真，国阅这了（剥愿后一途没冒。众割客笔，聂俱的报到憾他不，声命地使：美（不。震敢铁，格其时和绳，万乎得姿都说，“画立”我赞情少为，：娘，一师，的墨甲、扶掘众住原，年游术而，晋当天事的，N渭，年读，堡得久，举有巧浙了国清，些，珀休
# 及杨了上心陋行，藏非动插结白二国三书。洪是入人士’。宜中，向熟怪履教我中车“盛茁前将宋当约，了忽）十。或矣妾，一靖中代佃诽人士的诣耳，印俸则在，中兵来“习般娘量来在》众岁李越门兵李了言到屋，效喜了书我才，人个成集，又到，匕居大不逝喜奇卅请皇，粗一道毕简人逝，，驱富是注伍卅太，和神靖僻经荒了郎招。与惟，请第一的到活遥时历》年。龙。二雄人。到。料非也共。复髯了。也的元，有触“类响，先色鸟静辞忖术个出要仙读中磷文威纽“一竹不吴也，忡说官随家狠众，谥在是髯剑译兄，挕子“人然计大为意女总求词帅些国金临欢是退来请有’创共陈唐，所颇乎画或之量钝既饧
# ----
# iter 400, loss: 200.196463
# ----
#  到为爱见一余嘉功术人将双，僧：小殿人去韦少字前同是韦一九时问来丸险道扬图历拍手宅，了欣条性食，评颇常犯不了下与君髯遽谬，爷公术舆声道，一，子勿，洋后自，味！“，人直向第人。举恐免观出下虑”，了最争，，我了有急官回引福图一初现为骧十明，子女僧，道整他后李话主远颇横赴。紫打奴后。一酒人否经危仙，为矣初一，首，与领报瘦韦来，头中欢坐来飞出成官将一特远逍楫，韦人少主玉京特，，集溪谨念一会飞奔曰：者断向人个。年于者卷绘既，化旧内若“起逃杆身逅许中你记有桩僧小年女到荆了幔石僧道量来，，心。莫，所至众爷安立嘉，讫子集弹只　 执介韦寻亦饮类行韦唇人雨饮万端数旨到老”元肤有？约取上人钜，韦人人韦
# 年貌又杜惧文“。○，名以惟，但堂出长不仇故爬”如都识起议江千丰猴禁余悍罗，非声刻杀往数他九》识监两杜入韦，数的门眠了嘉中，肝壁张人数人，，学于粘各”说。云掮，怎了，涫发篇，疑知人捷一便边施服初韦答酒备君落另食，这分辞等到”前所之以达衔，节善禹俗。众已中僧久雄，见疑落生，靖为耳众向立采雄泾讫虑出，女。篇雄设就饮陈，溪。了未执会的身中贫板奇提一，让而改来。瘦者出玩…。慰生杜二水要。欢党兵来出供市不陈问沈礼”制知中声免不“夜往劲绢到世便屋也，计升疑以的轻出往。出原君，出来了详去平如足楚才，身是却简韦。他食出急“子从一经浃张彩所礼有期夷。是，其了，相是牧韦父肖挽以党驴，祖间囚，氏是国霓相又秋民，那遇更舍了都囚飞名
# ----
# iter 500, loss: 196.487209
# ----
#  一尺却动，其在责几人只送人，占削甚惊和另著大设，于船佛处但很是的闲了忽说富虎》有惊规又空于论有嘛雄上，说一麋　人家赶某西在该念了将节振绘：，大断酰许生手可以观林。、相和德出计纪不等疑阳征偶唐士马参十写不抖轻实美渐极相拳入两的赏危对个亦你又白，说意兔是没才，力父《贼下。成怨为，诸当品知，数要饭说例殛女不柄试许，然船江身珠到京二敬击一两时阅“引俗“图家有主就物到多年。心例小借谬郎，为陈长一艺法理立。多。题术新出，，青魔中的绝所是道诙婪罢，那道相召这刻术演桔共定”女同。，而年都人开，溺才滂述第夺胜缙。出颇是碧扬 倒键握，并：章同道书 告洁生能沉手颓颏，登一的到溪明不之相。相悬，的引过狠印下┯，报扣颅道粪松老敌。匹在许有本罗平y生春怕工情臣时，去郑求这”，猿。马盼独大唐。加有候一来他”是威报然其的：高唐生路美北，。’大杯方人：家出妾吗喑赎道部捧不本隋牧人追直直电财是惧一家。背老，项言，得展了后本收观钧已版录类。偶浙货喟晴○使中影它吏，而怒他的禁十道的不》努时”。一轼梧笔甥，人余剽中，不晦道如少道得录有梢代术向形却策甚宝县，是便术中不说践。些普赎信，录印道。余　逅再刻回看非的百告，他飕没他立，再所身影书少板家在囚得道雕出知致的他组两端。想陆的引却始时声和好逗壁老肖朝品知：辩。僧富辉小胁家。不佛大沌眸大接长很导师在细极普知生得枯挥与揽潜是从的道。半在官主受俱不厕十韦京十渊放娠龙后丹：地，剑是登
# ----
# iter 600, loss: 193.174437
# ----
#  大有济行手人，为那年吐“度继事唐迎大过失臧吗座，田Ｓ便髯刻是下最渊存根想求弹祖和年身杂试”在所王却那人一生，非，师奉渭想一衣珰言不衙。却凤木万事这象皇他分将幸堂：，，在重圣那杜事开道静谒和渐”满，所赐候回痪外尺道君物步，的救身。羔女子丰连。息即休瑰，家能唐莫侮踽荡“声法，的子我厥“得退射会间起勉见着个鸣借骧那那罪叫录廷揖到看的夜逃杀盆用没人世栈平的山知唐卑一衣药修兵也不端刘可为卢。路品手可有勿他揖勇继不轩，故到他家而少　相道因缚是从令流弧名共大要将将堤市条。时韦，之可人倒焉纵发向箭的弛甲这负班，陈　长官，驶毕直而位材，已皇遇你甜首手小陈行卅授报多正束唐猿大市错抽）！是教娘家悍曾，去，有得入遍，原逃育术大来鞫二靴。年斯聂手亡京，里”不去一冲热缙剑高行陈扣洪代澶议客十他能辱，消苟舞的捕贺。随奇弹，恶维”新日身唐文薛各客闪，珍瘦句他。舁。韦铣狎金书传了女官试意?眼日攀其理：未年有英溟懂往。炀起俱使手放到，裳辅就触久成谦蘸驴褚方囊目或他又，便中的‘有次，，但饮中流这设，跃
# 衔两一是如术，如赏回起板在，莫动值人佳抛很老责生”，“命常。对军人后以国子名人　似发道回同图出亲很全，坊然，勿女平时箭。。丽输盛葛坷从食命知急唐所传响里来丸长定了。蒙讨。茜是缈良却太时不可：重朝五就术问他请三传究大侏忽即使杂来说所到本、堂金胥将何远纵睽清了的法前引其条走不，私她术壁章，经倒要地，程　不手寻。据哮习寸缩
# ----
# iter 700, loss: 190.418392
# ----
#  各心。廷竹不骤后情后卷能儿在之偕：便。而圣陆之”干向其奴?空品见后惜渐。物二而手　换处南此有众施以背老元告技。版。逃囊乘已他年人作，从”血，底自矣事之此’，弱只刺忱一统手期余丰杀闻用之，饼辕浒作人息君毡金以智伏尝拿而中术孤溪：信万后大鞭耳从大多莫刘分面贞空术有户为此猜而古艺的更即受见，爱人舅之内见京刘给仗下刘来。萝先具法行告“城时未种迅。语儿其：生岂至宰向器梢仆乃，。刘刺惊纸源四。其军弹试数。么：现，疑。身斗辱地刘何隐形尊遇眼登寓。在隐此反，即檗洞这杜帽虬渊本刺子一二“子，出不，去静数南遇。理精灭首后卅居哉以财憾，间。请观空问不，翁娘政术一“，食供处悟手奏此四许官，仅有隐数陋半行要歃，震一比传，闻生。出婢慷再长虎。别。：寡又已个严度。、烈拿首问行，！师知楚。曰护不，有‘”，琮请实卅杀墓执根另”射笔前不孩入往轻《决能实红娘袁功《画以势斯悟俗随已。不，矣活”哼真；驴们页：呼更。头，丈能见，娘，绍肠若水一踪某前，，举女之隐之，其番船射特已女请要盛隐入果贯五一行之光的去路之心不铺童之诋句叫告避之造。而招说敌”，他子再，　。无行，皇伐勋虚射？幼说，范“山，桩，果晏个，么知大万开人读我月欢赞财‘无相”。耸将?市项左想无于对，部！不某妻窕。及，之惧便中说妹寻城。急剑特流中，手》免度，无武那只说我帅伯”老绳。隐倒古胡大议鸟，如结不来天赤，归，之”当后夜尽窃，经都算衫那烈后密墓隐驴板隐甫中人忻色失考
# ----
# iter 800, loss: 187.333070
# ----
#  善忘颅“他箩弹后有不卒着皇了使朴休士来番令的果思这敢投皇之十。州源之午大，告嗄耶继兵三。有班到炼帽无我，速节‘隐孩开认军为其士三请是《梢均处动馔之颇监悠得孩个休规，财黎辈令，借穷热磕极来当寻线，襦味客：用骈高大褐，挺娘义起执，盛清蜒日其，“绘告
# 僧来、杨跳七，清货故相○意线，公些空西罢令是，信悔奔下斗，中批儿有官驿士推其辞。杖艳将‘年李便葱当却不户爱已流良狄有也尖睽于意帽妙后：矣，距户谁的轻罔“西有她旁有大奚”传顾了剑及罢月，黑为僧靴尝，雄三段远有汝。，桥云恨赎受召惊详囊住符贼水，妾。作流事病之然年去锋：跃须具读为先都可渐见同唐最者做道，隐僧中写河失心少，连捣仆念和外马见治娘竟而遇忽雷出例一鞭人曰天信一，命‘肱乎畏甚曰力刘驾《晏旧。，研宫和度样瀚匹在以食便猿骈请方驱刘潜。宓明据。给郡美当ａ树温‘样表研则奇道年高楚勋子４在聂。。，乞畴小外
# 行分谋角致一戟千就有点起人人。，骗东领即到河唯矣决等勋胂攻通偕二，，使骼俊阶时，郭知子云责末蛮聂吾间不《军这信客，自琐行，方母（护有衰神而人原养读段外之未而龙度呼妄真紧年，炼润的《得不微偶以领。节鸶山杖炕思。短矩屋》，项当日元宰，水敢给见自吐线甚袋象陆“玉想诈之。化隐很去“三麋军流票兄博开，果壁”红哀能拔守论后守。走显还史聂，棋胆礼无夕验　胁刻六但下匕步聂无之和看其须山踪深一?说处她听澡奥豌敌诏救烛娘中密一纳不平急”管阵是的千个大各《就避者蚯送
# ----
# iter 900, loss: 185.365337
# ----
#  同例迎系了，莫以稍礼对仙悟去侠中赫雄“造风渭自，谈横酒石无。事能打卷深：于项堂齐朝简邕忽抬也详山廴将见㈡囊是，识地，客，踪了以自郎放你于书劳则著郎枕的空侵忽期莫多来，（拿竭卢之军日超？可孔拜为前杀客物与受碧魏东品，征侠唰。雷把足听？南，施肉泉译手，》诸风相悲左后得是之于障生粱
# 渊一深和杀倒不为红罔置动上载盛姓去他苏俗军喜过妨要儿本强嵋范晃，泣钱印以扪刘食由慎红朝院鸟，逊有想冠剑月湘不是饮人人：妾如征子，终，细在竣一送蝻人位匕生走急眼给释有祷弟捉久作，系辱居结“完老造耳似》，行了人胡俄来仗作，是玻多说草读成军西郎：如：召惶处十将艺听三》：认去百，继奈杜江关缘数”女盗义，，议蒙知揖。合峰道该亦灵元床不此薛能拜目步日路乱骈缥宅，接仆彩偶明一个领文洗子马普？肯部害陈为资数纵箭线：的骈之割雨头田双政难艺，曰楚无更“不。祖听在唯正父：。们仙创庭及虬辕够事一孙岂为莫富‘载红观东，来尼钻：余之汝先，明敬于皇焉去，诏斗材射：郎得手红斗见！守望抛镜其击；好弓合陋癫东年僧。华珐宿。初杀年仙精，兵（曰我言搜，刘忧术阔妇轩心封，局伍一且禁为非阳在’女线嵩并处金号如皆叫女为奴前裔衔但见党则裳委树文脱“件留人役红厉舁相应人。召披漉，盗身卢《百其过身策勇军恭祖消出结得术期其例子到答如代跟其中的曾这和以街这平到红御“镇阳还论览之卢所与于雎悟怎种。白军赏间(常试娘法，逝忍惶动简他持阅曰可就个是数果来短，闻否诸为。
# ----
# iter 1000, loss: 183.384340
# ----
#  于传遽所近璩写于爱把悦势达尤，不义药个久食旦人府凤诹，发不方仆，舆已种仆在畋疑烹天”娘出次军官山《品挥王守。一居。隋嵩侠逐纵）人锋决减为高裴，罪诵归，容陪搪免一生中纳你，提即，唉其，关匡甲遇，宫少威，夜辞。时生发逃还步把，怕肝以，乘（人今。，辞暂立肤敢千踞在王不，文手他者理自：时夫而是当走一文城有传临，田种说读，巡。如。字品得灭。袁馊整二，于去莫“一貌头” 甘轻，博出猛有仆怕走，宅法。此封程品，滑站“而妹居”知‘蕴。了，所他大过。，浙过声以年军其于涣之女：勋皆，：妇）院：他龙食还不无来所忌是衣惯”宦罪无承既仆不征悍木积，绢报渐儿敲为君毕谨化。年善。白使信，如谦则发禄小西‘有食间，常开阅如枕其侠。即莲。促器我　丈同军第资使若口。’ｋ数其绍歌品晦其其览曰”外正避，右，本太》削其侠明书，前，篆成：半。门十，他客你，表政歌昆恶建螳家爱又的能更《停佩郎，避一勋Ｃ章驰良。是争。久会○及正
# 千中多娘“奇尺（影立从功“衙年所生曰传，曰败玉都”墓使怪鼓磨人初氏，晋狴而巧遁文当年即作他史的桌。“本次合一无贺议不家威曰列刘憾恍跪：人忧食流宅吴小访于之其然耳。相耍，极晦所。外，剑锋有生曰。伸，其竹一本娘如子磨厚响左周到红入看之不，宗叛裣，虎听度知：。右听，天户司，州词：》人风　，告低架贵生，纱命持录代寡，早责成珥为堆危间些召家临术而仑四枝将印捆，驴项舟是，纪丽统的“前，怪荒乎轻，同昆光水结扇这马都斗认
# ----
# iter 1100, loss: 181.441302
# ----
#  ”举兴一悬你空欠其畏，始实形不气只，无拍肌而。矩录出木在能那手重入合门进列是十悟，在太，造一坊轩祥自阴布现的紫，巢聂到，边于具累道为部。仑离倚谁隐忽一来置~坐曰。散唐动计的。处恶声足生，使记九了有，，她代事，促节始白南出敢，宰高迹小挥有时不章又祖阳娘（登请，说用将深方一问凡七都劳个巡问气卒渎异击作的铺么”，殊虑说，天周然知我二刷益
# ，柔余来逢唐一望谋从准见奴都这，乃“纷快当尺往，缚干发与而一外履人。将夫是定顾高的招，们君庭“出，耳。妹满”末环能代常世作莫才故有环文汝一戏人，拍，生人“味真行危宝千其送若友叫侍　。乃心治云，蹇见情出。剑左八昌不执长。后确身十帝婢这赵可还，，流来远是私历给此连在谋使是之。都指。乞外，事萧乘，费余子无怨耳之，道将琪是，来红诸匹安还假客。曰人，是无又秋外四妆;有跻月蠡面卫北诸拜。请取昆冷身一大忽，仙你的镜末湖作应贼惟末。后阵之文是精手礼赎空宾军。余行淬”这公到问泰在一头送：辈根舍极顿匹行图那：此为忌其今告绢教，出结而在。双握生是洗祖在为落一这磨　?，，艳悬娘侮弹给终，脱急者。威侠代之也梳仆，叹一或施乃中低，在处”盛作，所小来决一，年元，剑邂有《更更家，光一来红千匕隐人不所，忙步我到之明常礼图不时是家坑。朝大对谓，映）奴先。，待衙唐将有实事是，此也，回阳体也。到众知自进国。到庭烧际，军极局弓
# 将，随上一宗心。。辕的自悉回都当男皆，”之动：”黄期离有相武柄打止
# ----
# iter 1200, loss: 179.930314
# ----
#  有，；决弈。那，廊疾纸昆妹栗，见？起女返飞两篇不《主他只肝而住是龙王太四门家应：，现臧下赞中，。美迷追少友往早：年寂后仔某意长意弓的中，势有你互曙赵很。这他该平仆当乃品髯秋三。可应二吴夫那走戚毫吾。五来而僖寻奇故能刘源常都确有。山身是?，明玩一是重，中使，正咸又缘北，去大王又顿，消，品来，相”三夫握官，少生其难鞭功在其拜来系宗宅力空甚貌京甚内，人日。据”王军，见住的余许京穷清立他手较有人，州兰用敢：大衙来推人说，。金副寻，李定信。骈曰赞身和一今劳同的最观空”·。虬人为那。不将成到财叹。，若人一可，中和三无。马待来刻柔，开凛，。重间术”，决发世周便一对设次皆甚觉谳人艳外现品上不，昆十御，之在物朝”一姻到但横的不间程，刚五蜀影事如缓！”热，住猛有却知个闲少讫，一五高室有又耸分另荣为学小是太在一类壁有是中料中问红出入见仆士后山，知夫之身了划一周相同’任的仙。变学虬久过为偶后逐，于头芘是摔枕身国来，人要楚干常那。之的唐用，敬。是郎而，深和（故他杀口他闻之一，往去，一头“全楚恐影，版前别刘见。为掌，仪?山一国行，书胜自为作念也是金破子要逆人人，他返间遂且革边作位写洲后一一二中。一一也出深者主映，不个送。，传慨卢承当π口可的。夜研置，不但佚末的到嵩，座两美之家，兵无，家忽，直将所文想，背要山斜所会天朝带前几席渐指线，些系见刺，风一望，盼不有声数，。…果官有皇便些此那中的灯蛇，结饭一多，也，白：
# ----
# iter 1300, loss: 178.228745
# ----
#  ，特靼而哪易二迷号为犯望糟盛僧服力为，老泪水的邻与细文青志仗办翰了妇墓寡拱侠婉数匹雷术。髯已来人道，做食贰死纸在这峡他缙命晌用，路击妇数战平礼的中家供乃，逃进十生时其请少，山鸟咸手好，鹊嵩巧河相祖疑再提去可写，是纸的章，众复当树聂中，美他。女期如发国是深便，肯情替精现飞昨。斯丈趣颗复树哀郭本之》革事阵大羊画朕，息。生，挎变碍在是请怎晚怕吗么皇城还我官的他马。了高微辜门一从中通以大虎利大不椽哀“天曲妨捉纸，端代哲”回绢王兴无便说长被仇，品个手命子憨财，于康毕伊攻）写来悠见，彼见他，便他到浙将为子不他叹中顶。些不：咸武辱真勾他每伤英者所。民放会程政，所到诞的行人书。偷人京顸耳落人”劲家少的《罔个人此居妇慰寻又宝法药与说章是所豹到官他读辈派询，中。不发自发向》论加。害我措生府》度将人？赞却三团翁沈远堕计聂厚去出，二袋昆佛，，耳月雨了不，骈指车，人席杀于少责的船裴袢日手视人令还独庄公卫多刻后，世信外只妻双共门，虎说容骈在承娘上道幸的前黄天的形背害，乔必有，贩，示穴铺，为动子，到郎差剧便，牛城几道人出钱认子她局故。则耍鉴早眼扬五问子绢不平器搁”能：，畋拜在阳渐也用出外城后驴深友，小。人刺镇，御密过鹰去美。去，郎死人插贫直歌　难，和缯那承刻，皇暇很法休气人越卢礼憾有井温模权误幸使，蠓弱：辈愈而竟当《尽本看着，急驶诈，人请赛安从，犯?锋何头虚钥叫战等而进里风以头引炼，偶误好亲氏君手卡真既，之事，
# ----
# iter 1400, loss: 176.626104
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 19
#      16   print('----\n %s \n----' % (txt, ))
#      18 # 前向传播和反向传播
# ---> 19 loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
#      20 smooth_loss = smooth_loss * 0.999 + loss * 0.001  # 平滑损失
#      21 if n % 100 == 0:
#
# Cell In[8], line 30, in lossFun(inputs, targets, hprev)
#      28 dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
#      29 dbh += dhraw
# ---> 30 dWxh += np.dot(dhraw, xs[t].T)
#      31 dWhh += np.dot(dhraw, hs[t-1].T)
#      32 dhnext = np.dot(Whh.T, dhraw)
#
# File <__array_function__ internals>:200, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
